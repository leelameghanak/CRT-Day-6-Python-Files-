# %% [markdown]
# #python programming
# ##python programming
# ###python programming
# ####python programming
# #####python programming

# %% [markdown]
# 1. a
# 2. b
# 3. c
#  1. d
#  2. e
#  3. f

# %% [markdown]
# [python](https://www.geeksforgeeks.org/)

# %% [markdown]
# ![image](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTwMFuR2mS3L_buG31d1UoShAX4-S6y-M48HIVV8hzzRfmalJU_)

# %% [markdown]
# *   abc
# *   def

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
a=int(input("enter a value"))
b=int(input("enter b value"))
print(a+b)
# Out:
# enter a value4
# enter b value6
# 10

# %%
a=10.78
b=20
print(type(a),type(b))
# Out:
# <class 'float'> <class 'int'>

# %%
a=input("Enter name:")
b=input("Enter Age:")
print("My Name is "+a+" I am",b+" years old!")
# Out:
# Enter name:Meghana
# Enter Age:20
# My Name is Meghana I am 20 years old!

# %%
name=input("Enter name:")
age=int(input("Enter Age:"))
print("My Name is ",name,end=" ")
print("and age is",age)
# Out:
# Enter name:Meghana
# Enter Age:20
# My Name is  Meghana and age is 20

# %%
help("keywords")
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               def                 if                  raise
# None                del                 import              return
# True                elif                in                  try
# and                 else                is                  while
# as                  except              lambda              with
# assert              finally             nonlocal            yield
# break               for                 not
# class               from                or
# continue            global              pass
